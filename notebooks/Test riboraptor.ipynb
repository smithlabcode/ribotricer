# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
sns.set_context('paper', font_scale=2.5)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
from riboraptor.normalization import deseq2_normalization

profiles = [[2,2,2,2,2],[60,60,760,60,60]]
fig = plt.figure(figsize=(24, 4))
ax = plt.subplot(121)
ax.plot(profiles[0], marker='o', color='#E69F00', label='sample1')
ax.plot(profiles[1], marker='o', color='#56B4E9', label='sample2')
plt.legend()
normalized_profile = deseq2_normalization(profiles)

ax = plt.subplot(122)
ax.plot(normalized_profile[0], marker='o', color='#E69F00', label='sample1')
ax.plot(normalized_profile[1], marker='o', color='#56B4E9', label='sample2')
plt.legend()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data  = [(2,60*3), (2,60*4), (2,760), (2,60), (2,60)]
profiles = zip(*data)

fig = plt.figure(figsize=(24, 4))
ax = plt.subplot(121)
ax.plot(profiles[0], marker='o', color='#E69F00', label='sample1')
ax.plot(profiles[1], marker='o', color='#56B4E9', label='sample2')
plt.legend()
normalized_profile = deseq2_normalization(profiles)

ax = plt.subplot(122)
ax.plot(normalized_profile[0], marker='o', color='#E69F00', label='sample1')
ax.plot(normalized_profile[1], marker='o', color='#56B4E9', label='sample2')
plt.legend()

# %%
data  = [(2,450), (2,160), (2,760), (2,170), (2,160)]
profiles = zip(*data)

fig = plt.figure(figsize=(24, 4))
ax = plt.subplot(121)
ax.plot(profiles[0], marker='o', color='#E69F00', label='sample1')
ax.plot(profiles[1], marker='o', color='#56B4E9', label='sample2')
plt.legend()
normalized_profile = deseq2_normalization(profiles)

ax = plt.subplot(122)
ax.plot(normalized_profile[0], marker='o', color='#E69F00', label='sample1')
ax.plot(normalized_profile[1], marker='o', color='#56B4E9', label='sample2')
plt.legend()
