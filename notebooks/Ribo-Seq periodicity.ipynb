# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Plotting" data-toc-modified-id="Plotting-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Plotting</a></div><div class="lev2 toc-item"><a href="#Fragment-length-distribution" data-toc-modified-id="Fragment-length-distribution-11"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Fragment length distribution</a></div><div class="lev2 toc-item"><a href="#Fragment-wise-read-distribution" data-toc-modified-id="Fragment-wise-read-distribution-12"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Fragment wise read distribution</a></div><div class="lev2 toc-item"><a href="#Metagene-line-plot" data-toc-modified-id="Metagene-line-plot-13"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Metagene line plot</a></div><div class="lev1 toc-item"><a href="#Counting" data-toc-modified-id="Counting-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Counting</a></div>

# %%
# %pylab inline
from ribocop.plotting import plot_fragment_dist, plot_framewise_dist, plot_continuous
import pickle
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Plotting
#
# ## Fragment length distribution

# %%
fragment_lengths = pickle.load(open('../data/T0.fragment_lengths.pickle'))
plot_fragment_dist(fragment_lengths)

# %% [markdown]
# ## Fragment wise read distribution

# %%
framewise_start_codons = pickle.load(open('../data/T0.coverage_start_codons.pickle'))
plot_framewise_dist(framewise_start_codons, range(28,32))

# %% [markdown]
# ## Metagene line plot

# %%
plot_continuous(framewise_start_codons, range(28,32))

# %% [markdown]
# # Counting

# %%
from ribocop.count_utilities import get_coverage, get_coverage_near_start_codons

## Gets coverage for each nucleotide covered in the bam
## by counting number of 5' end of reads at each position
## It's slow, so ideally should be run on server

coverage_dict = get_coverage('../data/T0.ribo.bam')

coverage_near_start_codons = get_coverage_near_start_codons(coverage_dict, 
                                                            '../data/annotation/gencode.v25.gffutils.start_codon.bed')
